# %% [raw]
# # MatPlotLib
# + **PRINCIAPL** Ferramenta para poltagem de gráficos no python que se assemelha ao matlab
# + (LINK GALLERRY)[https://matplotlib.org/gallery/index.html#]
#     + Possui muitos gráficos, muitos mesmos
#
# Matplotlib é a biblioteca "avô" de visualização de dados com o Python. Foi criado por John Hunter. Ele criou-a para tentar replicar os recursos de visualização de dados do MatLab (outro idioma de programação) no Python. Então, se você estiver familiarizado com matlab, aprender matplotlib será natural para você.
#
# É uma excelente biblioteca de gráficos 2D e 3D para gerar figuras científicas.
#
# Algumas das vantagens do Matplotlib são:
#
# Geralmente fácil de começar para plotagens simples
# Suporte para rótulos e textos personalizados
# Saída de alta qualidade em muitos formatos
# Muito personalizável em geral
# Matplotlib permite que você crie figuras reprodutíveis de forma programática. Vamos aprender a usá-lo! Antes de continuar esta palestra, sugiro que você dê uma olhada na página oficial do Matplotlib: http://matplotlib.org/
#
#
# ##### Mias links para leitura
# + http://www.matplotlib.org - A página web do projeto matplotlib.
# + https://github.com/matplotlib/matplotlib - O código fonte de matplotlib.
# + http://matplotlib.org/gallery.html - Uma grande galeria mostrando diversos tipos de gráficos que Matplotlib pode criar. Altamente recomendado!
# + http://www.loria.fr/~rougier/teaching/matplotlib - Um excelente tutorial sobre a biblioteca.
# + http://scipy-lectures.github.io/matplotlib/matplotlib.html - Outra excelente referência no asssunto.

# %%
## impsortaçao : vamos importar por enquanto so essa parte
import matplotlib.pyplot as plt

# %%
## Você também precisará usar essa linha para ver gráficos no notebook:
## sem isso, para mostrar um grfico tem que usar plot.show()
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(10, 21, 5)
x
# Out:
# array([10.  , 12.75, 15.5 , 18.25, 21.  ])

# %%
y = x ** 2
y
# Out:
# array([100.    , 162.5625, 240.25  , 333.0625, 441.    ])

# %% [markdown]
# #### Terminologia
# + `figure` :é a caixa onde fica a iamgem (quyalidade, tamanho, enfim, propriedades)
# + `axis` : relaciona ao que sera mostrado (plot, legenda, graficos e dados

# %%
## produz grafico eixo x e y respectivamernte
## procurar na doc, há varias outras formas e recursos nisso
plt.plot(x,y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Título')
# Out:
# Text(0.5,1,'Título')

# %%
# plt.subplot(nlinhas, ncols, numeroplot = refere a qual dos graficos vc vai trabalhar)
## nao tem 's' no final, o que tem 's' no final é mais OO e sera abordado mais na frente
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # Mais nas seções de cores abaixo
plt.subplot(1,2,2) ## numeroplot ta como 2 pois estamos nos referenindo a segunda figura
plt.plot(y, x, 'g*-');

# %% [markdown]
# #### Matplotlib Object Oriented Method
#
# Agora que vimos o básico, vamos acabar com uma introdução mais formal da API orientada a objetos da Matplotlib. Isso significa que vamos instanciar objetos de figuras e depois chamar métodos ou atributos desse objeto
#
# **Assim da mais controle sobre o seu layout**
#
# ###### Introdução ao Método Orientado a Objetos
#
# A principal idéia ao usar o método Object Oriented mais formal é criar objetos de figura e, em seguida, apenas chamar métodos ou atributos fora desse objeto. Esta abordagem é mais agradável ao lidar com uma tela que possui vários gráficos nela.
#
# Para começar, criamos uma figura de instância. Então, podemos adicionar eixos a essa figura:

# %%
# Cria uma figura vazia para iniciar o nosso trabalho
fig = plt.figure()

# Adiciona eixos à figura
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # esquerda, inferior, largura, altura (faixa de 0 a 1)
## se refere a % de disntancia da margem

# Plota nos eixos especificados
axes.plot(x, y, 'b')
axes.set_xlabel('Define o Label X') # Perceba o uso de "set_" para começar métodos
axes.set_ylabel('Define o Label Y')
axes.set_title('Define o Título Aqui')
# Out:
# Text(0.5,1,'Define o Título Aqui')

# %% [markdown]
# ##### Um grafico um dentro do outro

# %%
# Cria uma figura vazia
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # Eixo principal
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # Eixos inseridos

# Trabalhando no eixo maior
axes1.plot(x, y, 'b')
axes1.set_xlabel('Eixo X1')
axes1.set_ylabel('Eixo Y1')
axes1.set_title('Título 1')

# Trabalhando no eixo menor
axes2.plot(y, x, 'r')
axes2.set_xlabel('Eixo X2')
axes2.set_ylabel('Eixo Y2')
axes2.set_title('Título 2')
# Out:
# Text(0.5,1,'Título 2')

# %% [markdown]
# ##### Dois graficos no mesmo lugar

# %%
# Use semelhante a plt.figure (), exceto usar o desempacotamento da tupla para agarrar as figuras e os eixos
## tuple unpacking.= o plt.subplots() retorna uma tupla de dois. Dessa forma a primeira parte vai para fig e a segunda para axes
fig, axes = plt.subplots()

# Agora use o objeto dos eixos para adicionar coisas ao gráfico
axes.plot(x, y, 'r')
axes.plot(x, x*5, 'b')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Título');

# %% [markdown]
# ##### pondo varios graficos e plotando em cada um deles `subplots()`
# + Ao usasla o axes recebe uma lista ou lista de lista.
#     + Para em cada lugar plotar um grafico,, basta acessar por indice como array

# %%
## imprimes 3x3 graficos
fig, axes = plt.subplots(nrows=3, ncols=3)
plt.tight_layout() ## serve apra os graficos nao s sobreporem quando voce colocar muitos grtaficos
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE8C40B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE79CB5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE86DC8D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE7A8E940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE79C7390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE8ADBD68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE8B12DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE8B4FDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECE8B89DD8>]],
#       dtype=object)

# %%
for lv1 in axes:
    for lv2 in lv1:
        lv2.plot(x, x+15, 'red')
fig

# %%
### ou pode ser assim tambem
axes[1][1].plot(y,x,'g') ## vai ficar com dois graficos
fig

# %%
fig

# %% [markdown]
# ### Imagem da figura `.figure()`
# Matplotlib permite que a relação de aspecto, DPI e o tamanho da figura sejam especificados quando o objeto Figura é criado. Você pode usar os argumentos de palavras-chave figsize edpi.
# + `figsize` é uma tupla da largura e altura da figura em polegadas
# + `dpi` é o ponto por polegada (pixel por polegada).

# %%
## definmos que a figura tera essas qualidades
fig = plt.figure(figsize=(8,4), dpi=100)

fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('imagem com figure modificada');

# %% [markdown]
# A Matplotlib pode gerar saída de alta qualidade em vários formatos, incluindo PNG, JPG, EPS, SVG, PGF e PDF.
# + ***Ele é inteligente para salvar no tipo de extensao que passarmos apra ele**
# + Para salvar uma figura em um arquivo, podemos usar o método savefig da classeFigure:

# %%
## vai gerar imamge no path do notebook
fig.savefig("filename.png")

# %% [markdown]
# ### Legendas

# %% [markdown]
# Você pode usar o argumento ** label = "label text" ** quando parcelas ou outros objetos são adicionados à figura e, em seguida, usando o método ** legend ** sem argumentos para adicionar a legenda à figura:

# %%
# Ao dar o plot(), voce passa labels como parametro e aciona legende() pra mostrar
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()
## POSIÇÃO DA LGENDA: definia pelo loc
## ax.legend(loc=1) # Canto superior direito
## ax.legend(loc=2) # Canto superior esquerdo
## ax.legend(loc=3) # Canto inferior esquerdo
## ax.legend(loc=4) # Canto inferior direito
## ax.legend(loc=0) # deixe matplotlib decidir a localização ideal

# %% [markdown]
# #### Mais coisas de Layout

# %%
## relembrando nosso vetor
x
# Out:
# array([10.  , 12.75, 15.5 , 18.25, 21.  ])

# %%
# Cor e estilo da linha como MATLAB
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, x**2, 'b.-', linewidth=4) # linha azul tracejada
ax.plot(x, x**3, 'g--', alpha=0.5) # linha verde pontilhada
ax.set_xlim([10,20])## seta limite de eixo x
ax.set_ylim([0, 1600])## seta limite de eixo y

# linewidth = grossura d alinha
# alpha = tranparancia da linha
# linestyle = estilo da linha (tracejada, ponto pónto)

# no notebook que ele deixou, há vários estilos de linha
# Out:
# (0, 1600)
